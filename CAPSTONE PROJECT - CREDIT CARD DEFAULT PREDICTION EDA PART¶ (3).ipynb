# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">CAPSTONE PROJECT - CREDIT CARD DEFAULT PREDICTION </h1>

# %% [markdown]
# >### Importing Important libraries

# %%
# import 'Pandas' 
import pandas as pd 

# import 'Numpy' 
import numpy as np

# import subpackage of Matplotlib
import matplotlib.pyplot as plt

# import 'Seaborn' 
import seaborn as sns

# %% [markdown]
# >### Read the dataset UCI_Credit_Card.csv

# %%
df = pd.read_csv("UCI_Credit_Card.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %% [markdown]
# >### Basic understanding on the Dataset and EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %% [markdown]
# The following columns are quantitative/numerical:
# 'ID' , 'LIMIT_BAl' , 'AGE' , 'BILL_AMT1', 'BILL_AMT2','BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6','PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'.

# %% [markdown]
# The following columns are quantitative/categorical:
# 'SEX', 'EDUCATION', 'MARRIAGE' ,'PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6','default.payment.next.month'

# %%
#SEX

# %%
df['SEX'].unique()
# Out:
# array([2, 1], dtype=int64)

# %% [markdown]
# Gender:
# 1=male,
# 2=female

# %%
#EDUCATION

# %%
df['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0], dtype=int64)

# %% [markdown]
# 1=graduate school,
# 2=university,
# 3=high school,
# 4=others,
# 5=unknown,
# 6=unknown)

# %%
plt.figure(figsize = (6,5))
sns.countplot(x = 'EDUCATION', data = df)
plt.show()

# %%
#MARRIAGE

# %%
df['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %% [markdown]
# Marital status:
# 1=married,
# 2=single,
# 3=others

# %%
plt.figure(figsize = (6,5))
sns.countplot(x = 'MARRIAGE', data = df)
plt.show()

# %%
#PAY

# %%
df['PAY_0'].unique()
# Out:
# array([ 2, -1,  0, -2,  1,  3,  4,  8,  7,  5,  6], dtype=int64)

# %% [markdown]
# Repayment status in September, 2005
# -1=pay duly,
# 1=payment delay for one month,
# 2=payment delay for two months,
# …
# 8=payment delay for eight months,
# 9=payment delay for nine months and above

# %%
plt.figure(figsize = (6,5))
sns.countplot(x = 'PAY_0', data = df)
plt.show()

# %%
df['PAY_0'].value_counts().plot.bar()
plt.show()

# %% [markdown]
# variable PAY_0 to PAY_6 are ordinal categorical variable.

# %%
#default.payment.next.month

# %%
plt.figure(figsize = (6,5))
sns.countplot(x = 'default.payment.next.month', data = df)
plt.show()

# %% [markdown]
# Default payment (1=yes, 0=no)

# %%
#AGE

# %%
sns.distplot(x = df['AGE'])
plt.show()
# Out:
# C:\Users\VAISHNVI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The variable AGE is right skewed with low kurtosis.

# %% [markdown]
# Dataset is imbalanced.

# %% [markdown]
# >### Bivariate Analysis

# %% [markdown]
# Bi-Varite Analysis: Finding the relation between two variables like continious-continious, cont-cat, cat-cat values and ploting the appropiate graphs.

# %% [markdown]
# >#### Categorical to Categorical variables

# %%
# comparing education by gender
pd.crosstab(df['SEX'] , df['EDUCATION']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
df.SEX.value_counts() # SEX - Gender (1=male, 2=female)
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
SEX - Gender (1=male, 2=female) , More number of Females educated than men

# %%
#compairing Marital status by gender

pd.crosstab(df['SEX'] , df['MARRIAGE']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# Marital status (1=married, 2=single, 3=others), number of batchelors are more than married.Mos females are married.

# %%
#compairing PAY_0 by gender

pd.crosstab(df['PAY_0'] , df['SEX']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# Repayment status in September, 2005 (-1=pay duly, 0 = No cunsumption of credut card, 1=payment delay for one month, 2=payment delay for two months, …
#  8=payment delay for eight months, 9=payment delay for nine months and above).

# %% [markdown]
# Observed that most females are likely to Repay in September, 2005

# %%
#compairing PAY_0 by gender

pd.crosstab(df['PAY_2'] , df['SEX']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# Observed that most females are likely to Repay in August, 2005

# %%
#compairing default.payment.next.month by gender   # Default payment (1=yes, 0=no)

pd.crosstab(df['default.payment.next.month'] , df['SEX']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# females are more likely to default in payment then men ,according to the graph

# %%
# comparing education by Marital status

pd.crosstab(df['EDUCATION'] , df['MARRIAGE']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
EDUACTION - (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
Marital status (1=married, 2=single, 3=others)

# %% [markdown]
# Observed that most single men and women are university graduate

# %%
# comparing education by Marital PAY_3
pd.crosstab(df['EDUCATION'] , df['PAY_3']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
Repayment status in September, 2005 (-1=pay duly, 0 = No cunsumption of credut card, 1=payment delay for one month, 2=payment delay for two months, …
 8=payment delay for eight months, 9=payment delay for nine months and above).

# %% [markdown]
# 1.observed that most educated (university graduates) are most likely to not cumsume credit card at all.
# 2.Most school graduates are likely to pay on time.

# %%
# comparing education by Marital PAY_4
pd.crosstab(df['EDUCATION'] , df['PAY_4']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# 1.observed that most educated (university graduates) are most likely to not cumsume credit card at all.
# 2.Most school graduates are likely to pay on time.

# %%
# comparing education by default.payment.next.month
pd.crosstab(df['EDUCATION'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# Observed that university graduates are most likely to default on credit card bill repayment.

# %% [markdown]
# >### MARRIAGE

# %%
 # comparing MARRIAGE by PAY_5
pd.crosstab(df['MARRIAGE'] , df['PAY_5']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# Most single people are likely to to repay on time in May, 2005

# %%
 # comparing MARRIAGE by PAY_6
pd.crosstab(df['MARRIAGE'] , df['PAY_6']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
Marital status (1=married, 2=single, 3=others)

# %%
Most single people are likely to to repay on time in April, 2005

# %%
 # comparing MARRIAGE by 'default.payment.next.month
pd.crosstab(df['MARRIAGE'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# observed that most single people are likely to repay on time.

# %%
 # comparing PAY_0 by PAY_3

pd.crosstab(df['PAY_0'] , df['PAY_3']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_0 by default.payment.next.month

pd.crosstab(df['PAY_0'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# In Repayment status in September, 2005 , high chances of payment delay for two months

# %%
 # comparing PAY_2 by PAY_3
    
pd.crosstab(df['PAY_2'] , df['PAY_3']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_2 by PAY_4
    
pd.crosstab(df['PAY_2'] , df['PAY_4']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_2 by default.payment.next.month

pd.crosstab(df['PAY_2'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_3 by default.payment.next.month

pd.crosstab(df['PAY_3'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_4 by default.payment.next.month

pd.crosstab(df['PAY_4'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %%
 # comparing PAY_5 by default.payment.next.month

pd.crosstab(df['PAY_5'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2364/2786675758.py in <module>
#       1 # comparing PAY_5 by default.payment.next.month
#       2
# ----> 3 pd.crosstab(df['PAY_5'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
#       4 plt.show()
#
# NameError: name 'pd' is not defined

# %%
 # comparing PAY_6 by default.payment.next.month

pd.crosstab(df['PAY_'] , df['default.payment.next.month']).plot(kind = 'bar' , figsize = (10,7))
plt.show()

# %% [markdown]
# >#### Numerical to Numerical variables

# %%
sns.scatterplot(df['BILL_AMT1'],df['LIMIT_BAL'])
plt.show()

# %% [markdown]
# we can observe that BILL_AMT1 and LIMIT_BAL has Stronger positive correlation

# %%
d1=df.groupby('AGE')['BILL_AMT1'].mean().plot()

# %% [markdown]
# The bill amount increases with increase in Age

# %%
sns.heatmap(df[['BILL_AMT1','BILL_AMT2']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is positive correlatation between BILL_AMT1 and BILL_AMT2

# %%
sns.scatterplot(df['BILL_AMT1'],df['BILL_AMT3'])
plt.show()

# %% [markdown]
# We can observer a slight positive correlation and can observer outliers in the graph

# %%
sns.scatterplot(df['BILL_AMT1'],df['BILL_AMT4'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and BILL_AMT4 has Stronger positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['BILL_AMT5'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and BILL_AMT5 has Stronger positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['BILL_AMT6'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and BILL_AMT6 has slight positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT1'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and PAY_AMT1 has very less positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT2'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and PAY_AMT2 has very less positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT3'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and PAY_AMT3 has very less positive correlation With some outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT4'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and PAY_AMT4 has very less positive correlation With more numbers of outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT5'])
plt.show()

# %% [markdown]
#  We can observe that BILL_AMT1 and PAY_AMT5 has positive correlation With many outliers

# %%
sns.scatterplot(df['BILL_AMT1'],df['PAY_AMT6'])
plt.show()

# %% [markdown]
# We can observe that BILL_AMT1 and PAY_AMT6 hasless positive correlation With many outlier

# %%
sns.scatterplot(df['BILL_AMT2'],df['LIMIT_BAL'])
plt.show()

# %% [markdown]
# we can observe that BILL_AMT2 and LIMIT_BAL has Stronger positive correlation  with some outliers

# %%
d2=df.groupby('AGE')['BILL_AMT2'].mean().plot()

# %% [markdown]
# the billamount_2 increases with increase in Age

# %%
sns.scatterplot(df['BILL_AMT2'],df['BILL_AMT3'])
plt.show()

# %% [markdown]
# We can observer a slight positive correlation and can observer outliers in the graph

# %%
sns.scatterplot(df['BILL_AMT2'],df['BILL_AMT4'])
plt.show()

# %% [markdown]
# We can observer a strong positive correlation and can observer outliers in the graph

# %%
sns.scatterplot(df['BILL_AMT2'],df['BILL_AMT5'])
plt.show()

# %% [markdown]
# We can observer a strong positive correlation and can observer outliers in the graph

# %%
sns.scatterplot(df['BILL_AMT2'],df['BILL_AMT6'])
plt.show()

# %% [markdown]
# We can observer a slight positive correlation and can observer outliers in the graph

# %%
sns.heatmap(df[['BILL_AMT2','PAY_AMT1']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT2 and PAY_AMT1

# %%
sns.heatmap(df[['BILL_AMT2','PAY_AMT2']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT2 and PAY_AMT2

# %%
sns.heatmap(df[['BILL_AMT2','PAY_AMT3']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT2 and PAY_AMT3

# %%
sns.heatmap(df[['BILL_AMT2','PAY_AMT4']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT2 and PAY_AMT4

# %%
d3= sns.lmplot(x="BILL_AMT2",y="PAY_AMT5", data=df)

# %%
sns.heatmap(df[['BILL_AMT2','PAY_AMT6']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT2 and PAY_AMT6

# %%
sns.scatterplot(df['BILL_AMT3'],df['LIMIT_BAL'])
plt.show()

# %%
d3=df.groupby('AGE')['BILL_AMT3'].mean().plot()

# %% [markdown]
# the billamount_3 increases with increase in Age

# %%
sns.scatterplot(df['BILL_AMT3'],df['BILL_AMT4'])
plt.show()

# %%
sns.scatterplot(df['BILL_AMT3'],df['BILL_AMT5'])
plt.show()

# %%
sns.scatterplot(df['BILL_AMT3'],df['BILL_AMT6'])
plt.show()

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT1']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is  less postive  correlatation between BILL_AMT3 and PAY_AMT1

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT2']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is  less postive  correlatation between BILL_AMT3 and PAY_AMT2

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT3']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT3 and PAY_AMT3

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT4']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT3 and PAY_AMT4

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT5']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT3 and PAY_AMT5

# %%
sns.heatmap(df[['BILL_AMT3','PAY_AMT6']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is very less postive  correlatation between BILL_AMT3 and PAY_AMT6

# %% [markdown]
# >##### Variables to Target

# %%
#Removing insignificant variable
df=df.drop("ID",axis=1)
df.head()
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0  20000.000000    2          2         1   24      2      2     -1     -1
# 1 120000.000000    2          2         2   26     -1      2      0      0
# 2  90000.000000    2          2         2   34      0      0      0      0
# 3  50000.000000    2          2         1   37      0      0      0      0
# 4  50000.000000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6    BILL_AMT1    BILL_AMT2    BILL_AMT3    BILL_AMT4  \
# 0     -2     -2  3913.000000  3102.000000   689.000000     0.000000
# 1      0      2  2682.000000  1725.000000  2682.000000  3272.000000
# 2      0      0 29239.000000 14027.000000 13559.000000 14331.000000
# 3      0      0 46990.000000 48233.000000 49291.000000 28314.000000
# 4      0      0  8617.000000  5670.000000 35835.000000 20940.000000
#
#      BILL_AMT5    BILL_AMT6    PAY_AMT1     PAY_AMT2     PAY_AMT3    PAY_AMT4  \
# ...

# %%
plt.figure(figsize=(100,50))
df.drop("default.payment.next.month",axis=1).hist(bins=10)
#plt.tight_layout()
plt.show()
print("Skewness:")
df.drop("default.payment.next.month",axis=1).skew()
#x.set_xticklabels(x_ticks, rotation=0, fontsize=5)
#x.set_yticklabels(y_ticks, rotation=0, fontsize=5)
# Out:
# Skewness:
# LIMIT_BAL    0.992867
# SEX         -0.424183
# EDUCATION    0.970972
# MARRIAGE    -0.018742
# AGE          0.732246
# PAY_0        0.731975
# PAY_2        0.790565
# PAY_3        0.840682
# PAY_4        0.999629
# PAY_5        1.008197
# PAY_6        0.948029
# BILL_AMT1    2.663861
# BILL_AMT2    2.705221
# BILL_AMT3    3.087830
# BILL_AMT4    2.821965
# BILL_AMT5    2.876380
# BILL_AMT6    2.846645
# PAY_AMT1    14.668364
# PAY_AMT2    30.453817
# PAY_AMT3    17.216635
# PAY_AMT4    12.904985
# PAY_AMT5    11.127417
# PAY_AMT6    10.640727
# dtype: float64

# %%
sns.countplot(df.SEX)
plt.show()

# %%
sns.countplot(df.EDUCATION)
plt.show()

# %%
sns.countplot(df.MARRIAGE)
plt.show()

# %%
dft=df["default.payment.next.month"]
dft.value_counts()
sns.countplot(x=dft)
plt.text(x=-0.05,y=dft.value_counts()[0]+1,s=str(round((dft.value_counts()[0])*100/len(dft),2))+"%")
plt.text(x=0.95,y=dft.value_counts()[1]+1,s=str(round((dft.value_counts()[1])*100/len(dft),2))+"%")
plt.show()

# %%
This graph shows the distribution of people belongs to default on credit card class and do not default on credit card class

# %%
plt.figure(figsize=(35,28))
sns.boxplot(data=df,orient="h")
plt.show()

# %%
df.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count   30000.000000 30000.000000 30000.000000 30000.000000 30000.000000
# mean   167484.322667     1.603733     1.853133     1.551867    35.485500
# std    129747.661567     0.489129     0.790349     0.521970     9.217904
# min     10000.000000     1.000000     0.000000     0.000000    21.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    34.000000
# 75%    240000.000000     2.000000     2.000000     2.000000    41.000000
# max   1000000.000000     2.000000     6.000000     3.000000    79.000000
#
#              PAY_0        PAY_2        PAY_3        PAY_4        PAY_5  \
# count 30000.000000 30000.000000 30000.000000 30000.000000 30000.000000
# mean     -0.016700    -0.133767    -0.166200    -0.220667    -0.266200
# std       1.123802     1.197186     1.196868     1.169139     1.133187
# ...

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
#Comparing Numerical and Categorical variables with target variable.
sns.catplot(x="default.payment.next.month",y="LIMIT_BAL",kind="bar",data=df)
plt.show()
#from graph we can say that a client will default on their credit card payment if he has less balance in his account.
#but the data is not distributed properly.

# %%
sns.catplot(x="default.payment.next.month",y='SEX',hue="SEX",kind="bar",data=df)
plt.show()
#this tells that,females are more likely to default on credit card
#SEX: Gender(1=male, 2=female)

# %%
sns.catplot(x="default.payment.next.month",y="EDUCATION",hue="EDUCATION",kind="bar",data=df)
plt.show()
#EDUCATION almost fails to gives us insights to predict whether the person will default on credit card or not

# %%
sns.catplot(x="default.payment.next.month",y='MARRIAGE',hue='MARRIAGE',kind="bar",data=df)
plt.show()
#from this graph also we can say that marriage also fails to predict the target variable.

# %%
sns.catplot(x="default.payment.next.month",y='PAY_0',hue='PAY_0',kind="bar",data=df)
plt.show()

# %%
sns.catplot(x="default.payment.next.month",y='PAY_2',hue='PAY_2',kind="bar",data=df)
plt.show()

# %%
sns.catplot(x="default.payment.next.month",y="AGE",kind="box",data=df)
plt.show()
#It looks like age is also not a good variable to predict the target,
#because the people belogs to age around 28 to 42 are there in both section who will default the credit card as well who will not.

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT1",kind="bar",data=df)
plt.show()
#This graph says that the possibility that people default on credit card is less if the bill amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT2",kind="bar",data=df)
plt.show()
#this also gives the same inference as graph drawn above

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT3",kind="bar",data=df)
plt.show()
#It looks like,this variable BILL_AMT3 is helpful to predict the target, because those who have more bill amount are not going to default on credit card.

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT4",kind="bar",data=df)
plt.show()
##This graph says that the possibility that people default on credit card is less if the bill amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT5",kind="bar",data=df)
plt.show()
##This graph says that the possibility that people default on credit card is less if the bill amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y="BILL_AMT6",kind="bar",data=df)
plt.show()
#couldnt understand this graph, and it may nit help us to predict the target variable properly

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT1',kind="bar",data=df)
plt.show()
##This graph says that the possibility that people default on credit card is less if the pay amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT2',kind="bar",data=df)
plt.show()
##This graph says that the possibility that people default on credit card is less if the pay amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT3',kind="bar",data=df)
plt.show()
##This graph says that the possibility that people default on credit card is less if the pay amount is more of that person

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT4',kind="bar",data=df)
plt.show()
##This graph may fail to predict the target variable, so it's better to not consider the variable pay_amt4

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT5',kind="bar",data=df)
plt.show()
##This graph may fail to predict the target variable, so it's better to not consider the variable pay_amt4

# %%
plt.figure(figsize=(30,20))
sns.catplot(x="default.payment.next.month",y='PAY_AMT6',kind="bar",data=df)
plt.show()
#To some extent this variable may help us to predict the target variable
